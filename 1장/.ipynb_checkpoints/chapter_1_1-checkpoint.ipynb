# %% [markdown]
# ## 예제 1-1-1 키워드 알아보기

# %%
import keyword

# %%
len(keyword.kwlist)
# Out:
# 33

# %%
type(keyword.kwlist)
# Out:
# list

# %%
count = 0
for i in keyword.kwlist :
    print(i,end=", ")
    count += 1
    if count % 5  == 0 :
        print()
# Out:
# False, None, True, and, as,
# assert, break, class, continue, def,
# del, elif, else, except, finally,
# for, from, global, if, import,
# in, is, lambda, nonlocal, not,
# or, pass, raise, return, try,
# while, with, yield,

# %% [markdown]
# ## 예제 1-1-2 예약어를 다른 변수로 사용하기

# %%
if = 100
# Out:
#   File "<ipython-input-8-3abe269c51ad>", line 1
#     if = 100
#        ^
# SyntaxError: invalid syntax

# %%
in = 100
# Out:
#   File "<ipython-input-9-a013e2e46592>", line 1
#     in = 100
#      ^
# SyntaxError: invalid syntax
