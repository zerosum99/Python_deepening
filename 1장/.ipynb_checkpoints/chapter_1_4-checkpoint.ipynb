# %% [markdown]
# ## 예제 1-4-1 빌드인과 전역 이름공간 알아보기

# %%
__builtin__
# Out:
# <module 'builtins' (built-in)>

# %%
__builtin__.globals
# Out:
# <function globals()>

# %%
i = 100

# %%
globals()['i']
# Out:
# 100

# %%
__builtin__.vars
# Out:
# <function vars>

# %%
vars()['i']
# Out:
# 100

# %%
def add(x,y) :
    return x+y

# %%
globals()['add']
# Out:
# <function __main__.add(x, y)>

# %%
add.__globals__['i']
# Out:
# 100
